# %% [markdown]
# <a href="https://colab.research.google.com/github/Vrishali04/Cardiovascular_Risk_Prediction_Classification_Capstone_Project/blob/main/Cardiovascular_risk_prediction_classification_capstone_project_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Cardiovascular_Risk_Prediction_Classification_Capstone_Project/data_cardiovascular_risk.csv')

# %%
df.shape
# Out:
# (3390, 17)

# %%
df
# Out:
#         id  age  education sex is_smoking  cigsPerDay  BPMeds  \
# 0        0   64        2.0   F        YES         3.0     0.0
# 1        1   36        4.0   M         NO         0.0     0.0
# 2        2   46        1.0   F        YES        10.0     0.0
# 3        3   50        1.0   M        YES        20.0     0.0
# 4        4   64        1.0   F        YES        30.0     0.0
# ...    ...  ...        ...  ..        ...         ...     ...
# 3385  3385   60        1.0   F         NO         0.0     0.0
# 3386  3386   46        1.0   F         NO         0.0     0.0
# 3387  3387   44        3.0   M        YES         3.0     0.0
# 3388  3388   60        1.0   M         NO         0.0     NaN
# 3389  3389   54        3.0   F         NO         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    221.0  148.0   85.0    NaN
# ...

# %%
fig, ax = plt.subplots(figsize=(20, 15))

# Plot box plots of all numeric columns
sns.boxplot(data=data.select_dtypes(include=['float64']), ax=ax)


# Show the plot
plt.show()

# %% [markdown]
# # Inference :
#
# From the above box plot, we can observe the following insights:
#
# * The distribution of cigsPerDay is positively skewed, meaning most people are non-smokers and a small number of people smoke a lot.
#
# * The distribution of BMI has a positive skew, with a large number of people having a low BMI and a small number of people having a high BMI.
#
# * The distribution of heartRate is positively skewed, meaning that most people have a low heart rate, and a small number of people have a high heart rate.
#
# * The distribution of glucose is positively skewed, meaning that most people have a low glucose level, and a small number of people have a high glucose level.
#
# * The distribution of sysBP and diaBP have similar shapes, with a positive skew and a large number of people having a low blood pressure and a small number of people having a high blood pressure.

# %%
columns = df.select_dtypes(include=np.number).columns.tolist()

n = 1

plt.figure(figsize=(20,15))

for column in columns:   
    
    plt.subplot(5,4,n)
    
    n = n+1
    sns.distplot(df[column], bins = 100)
    
    plt.tight_layout()
