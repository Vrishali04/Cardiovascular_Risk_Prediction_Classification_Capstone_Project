# %% [markdown]
# <a href="https://colab.research.google.com/github/Vrishali04/Cardiovascular_Risk_Prediction_Classification_Capstone_Project/blob/main/Cardiovascular_risk_prediction_classification_capstone_project_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Cardiovascular_Risk_Prediction_Classification_Capstone_Project/data_cardiovascular_risk.csv')

# %%
df.shape
# Out:
# (3390, 17)

# %%
df
# Out:
#         id  age  education sex is_smoking  cigsPerDay  BPMeds  \
# 0        0   64        2.0   F        YES         3.0     0.0
# 1        1   36        4.0   M         NO         0.0     0.0
# 2        2   46        1.0   F        YES        10.0     0.0
# 3        3   50        1.0   M        YES        20.0     0.0
# 4        4   64        1.0   F        YES        30.0     0.0
# ...    ...  ...        ...  ..        ...         ...     ...
# 3385  3385   60        1.0   F         NO         0.0     0.0
# 3386  3386   46        1.0   F         NO         0.0     0.0
# 3387  3387   44        3.0   M        YES         3.0     0.0
# 3388  3388   60        1.0   M         NO         0.0     NaN
# 3389  3389   54        3.0   F         NO         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    221.0  148.0   85.0    NaN
# ...

# %%
fig, ax = plt.subplots(figsize=(20, 15))

# Plot box plots of all numeric columns
sns.boxplot(data=data.select_dtypes(include=['float64']), ax=ax)


# Show the plot
plt.show()

# %% [markdown]
# # Inference :
#
# From the above box plot, we can observe the following insights:
#
# * The distribution of cigsPerDay is positively skewed, meaning most people are non-smokers and a small number of people smoke a lot.
#
# * The distribution of BMI has a positive skew, with a large number of people having a low BMI and a small number of people having a high BMI.
#
# * The distribution of heartRate is positively skewed, meaning that most people have a low heart rate, and a small number of people have a high heart rate.
#
# * The distribution of glucose is positively skewed, meaning that most people have a low glucose level, and a small number of people have a high glucose level.
#
# * The distribution of sysBP and diaBP have similar shapes, with a positive skew and a large number of people having a low blood pressure and a small number of people having a high blood pressure.

# %%
columns = df.select_dtypes(include=np.number).columns.tolist()

n = 1

plt.figure(figsize=(20,15))

for column in columns:   
    
    plt.subplot(5,4,n)
    
    n = n+1
    sns.distplot(df[column], bins = 100)
    
    plt.tight_layout()

# %%
plt.hist(data['age'], bins=10, color='blue')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age Distribution')
plt.show()

# %% [markdown]
# ## Inference :
#
# * From the plot, we can see that most of the individuals in the data set are between the ages of 40 and 70. There is a relatively lower number of individuals in the age groups of 20-40 and 70-90.

# %%
sns.set()

# %%
plt.hist(data['cigsPerDay'], bins=10, color='blue')
plt.xlabel('Cigarettes per Day')
plt.ylabel('Frequency')
plt.title('Cigarettes per Day Distribution')
plt.show()

# %% [markdown]
# # Inference :
# * The histogram of cigsPerDay shows that the majority of individuals in the data set either do not smoke or smoke less than 10 cigarettes per day.

# %%
plt.hist(data['totChol'], bins=10, color='blue')
plt.xlabel('Total Cholesterol')
plt.ylabel('Frequency')
plt.title('Total Cholesterol Distribution')
plt.show()

# %% [markdown]
# # Inference :
# * The histogram of totChol shows that the majority of individuals have total cholesterol levels between 200 and 300 mg/dL.

# %%
plt.boxplot(data['sysBP'], vert=False)
plt.xlabel('Systolic Blood Pressure')
plt.title('Systolic Blood Pressure Distribution')
plt.show()

# %% [markdown]
# # Inference :
#
# * The median systolic blood pressure value is around 135 mmHg.
# *The lower and upper quartiles are around 120 and 150 mmHg, respectively, meaning that 50% of the values in the column lie between these values.
# *There are potential outliers present in the distribution, indicated by the dots beyond the whiskers of the plot. These values could be further investigated to determine if they are true outliers or if they represent valid data points.

# %%
sns.violinplot(data['BMI'], color='purple')
plt.xlabel('Body Mass Index')
plt.title('Body Mass Index Distribution')
plt.show()
# Out:
# C:\Users\aspirex99\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Inference :
#
# * The distribution of BMI values is roughly symmetrical, with a single mode at around 25.
#
# * There are some values on the higher end of the distribution that are likely to represent higher BMIs.
# * There may be multiple modes in the distribution, as indicated by the multiple peaks in the violin plot. This could suggest the presence of different subgroups with different BMI values within the data.

# %%
sns.barplot(x='sex', y='TenYearCHD', data=data)
plt.show()

# %% [markdown]
# # Inference :
#
# * The bar plot shows the relationship between the 'sex' and 'TenYearCHD' variables.
#  * From the plot, it can be observed that males have a higher likelihood of having a heart disease in the next 10 years compared to females.

# %%
# Plot a scatterplot of totChol vs age
sns.scatterplot(x="age", y="totChol", data=data)
plt.show()

# %% [markdown]
# # Inference :
# * The scatter plot indicates that as the age of an individual increases, their total cholesterol levels also tend to increase. This relationship appears to be positive and relatively linear, meaning that as one variable increases, the other tends to increase as well. This could indicate that age and total cholesterol levels are related and that older individuals may be at a higher risk of high cholesterol and its associated health problems.

# %%
# Plot a line plot of sysBP vs age
sns.lineplot(x="age", y="sysBP", data=data)
plt.show()

# %% [markdown]
# # Inference :
# * The age of an individual increases, their systolic blood pressure also tends to increase. This relationship appears to be positive and relatively linear, meaning that as one variable increases, the other tends to increase as well. This could indicate that age and systolic blood pressure are related and that older individuals may be at a higher risk of high blood pressure and its associated health problems.

# %%
# Plot a bar plot of education vs TenYearCHD
sns.barplot(x="education", y="TenYearCHD", data=data)
plt.show()

# %% [markdown]
# # Inference :
#
# * The bar plot shows the average value of the TenYearCHD variable for different levels of education. From the plot, it appears that as the education level increases, the average value of TenYearCHD decreases. This indicates that higher levels of education might be associated with a lower risk of having a heart disease event within the next 10 years. However, it is important to keep in mind that correlation does not necessarily imply causation, and other factors such as income, lifestyle, and access to healthcare could also be contributing to this relationship.

# %%
# Plot a box plot of glucose vs is_smoking
sns.boxplot(x="is_smoking", y="glucose", data=data)
plt.show()

# %% [markdown]
# # Inference :
#
# * Median, quartiles, and outliers for each group. It appears that the median glucose level is slightly higher for people who smoke compared to those who do not smoke. However, the overall range of glucose levels is similar for both groups. This suggests that there is no strong association between smoking and glucose levels.

# %%
# Plot a violin plot of BMI vs prevalentStroke
sns.violinplot(x="prevalentStroke", y="BMI", data=data)
plt.show()

# %% [markdown]
# # Inference :
#
# * For those individuals who have a prevalent stroke, the distribution of their BMI values is more spread out and is centered around a higher value compared to those who do not have a prevalent stroke.
# * The majority of individuals with a prevalent stroke have a higher BMI compared to those who do not have a prevalent stroke.
# * Some individuals with a prevalent stroke have a BMI value that falls in the lower range, indicating that not all individuals with a prevalent stroke have a higher BMI.

# %%
# Plot a swarm plot of heartRate vs diabetes
sns.swarmplot(x="diabetes", y="heartRate", data=data)
plt.show()
# Out:
# C:\Users\aspirex99\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 78.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # Inference :
# * It can be observed that individuals without diabetes have a higher heart rate compared to those with diabetes. This could indicate a potential relationship between diabetes and heart rate, where individuals with diabetes have a lower heart rate compared to those without diabetes.

# %%
# Plot a count plot of sex
sns.countplot(x="sex", data=data)
plt.show()

# %% [markdown]
# # Inference :
#
# * We can see that females are having more count than the males in the data set.

# %% [markdown]
# # Inference :
#
# * We can see that females are having more count than the males in the data set.

# %%
# Plot a histogram of diaBP
sns.histplot(data["diaBP"])
plt.show()

# %% [markdown]
# # Inference :
#
# * The shape of the histogram can provide information on the skewness of the data and the presence of outliers. In this plot, it can be observed that most of the values lie in the range of 60 to 80, with a peak in the range of 70 to 75. It can be concluded that the majority of the participants in the study have a diastolic blood pressure in the normal range.

# %%
sns.boxenplot(x="TenYearCHD", y="BMI", data=data)
plt.show()

# %% [markdown]
# # Inference :
#
# * We can observe that the median BMI values of individuals with TenYearCHD = 0 is slightly higher than that of individuals with TenYearCHD = 1. This indicates that individuals with higher BMI are less likely to have CHD in the next 10 years.
#
# * However, the interquartile range of BMI values is similar for both categories of TenYearCHD, indicating that there is a similar spread of BMI values for both categories. The outliers on the right side of the plot are individuals with a high BMI value who did not have CHD in the next 10 years, which might suggest that BMI alone is not a decisive factor for CHD. Further analysis, such as exploring the relationship between other variables and CHD, is necessary to draw more comprehensive conclusions.

# %%
sns.jointplot(x="sysBP", y="diaBP", data=data)
plt.show()

# %% [markdown]
# # Inference  :
#
# * We can observe that there is a positive relationship between systolic and diastolic blood pressure, meaning that as systolic blood pressure increases, diastolic blood pressure also increases. The plot also shows the distribution of each variable through the histograms on either side of the plot. This information can be useful in understanding the distribution of the two variables and any potential outliers.

# %%
columns = df.select_dtypes(include=np.number).columns.tolist()

n = 1

plt.figure(figsize=(20,15))

for column in columns:   
    
    plt.subplot(5,4,n)
    
    n = n+1
    sns.barplot(x=column, y="TenYearCHD", data=df)
    
    plt.tight_layout()

# %%
df = df.drop(df.select_dtypes(include = 'object').columns.tolist(),axis = 1)

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, recall_score, precision_score, roc_auc_score, roc_curve
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB

# load the data set
data = df

# drop the missing values
data = data.dropna()

# Split the data set into feature variables and target variable
X = data.drop("TenYearCHD", axis=1)
y = data["TenYearCHD"]

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Create a list of classifiers
classifiers = [LogisticRegression(), DecisionTreeClassifier(), RandomForestClassifier(), KNeighborsClassifier(), SVC(), GaussianNB()]

# Loop through the classifiers and fit each to the training data
for clf in classifiers:
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
    
    # Print the recall, precision, and confusion matrix for each classifier
    print("Classifier:", clf.__class__.__name__)
    print("Recall:", recall_score(y_test, y_pred))
    print("Precision:", precision_score(y_test, y_pred))
    print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
    
    # Plot the ROC curve and print the AUC score
    fpr, tpr, thresholds = roc_curve(y_test, y_pred)
    roc_auc = roc_auc_score(y_test, y_pred)
    plt.plot(fpr, tpr, label='%s ROC (area = %0.2f)' % (clf.__class__.__name__, roc_auc))
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic')
    plt.legend(loc="lower right")

# Show the plot
plt.show()

# Print the classification report
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Classifier: LogisticRegression
# Recall: 0.031914893617021274
# Precision: 0.5
# Confusion Matrix:
#  [[489   3]
#  [ 91   3]]
# Classifier: DecisionTreeClassifier
# Recall: 0.23404255319148937
# Precision: 0.24175824175824176
# Confusion Matrix:
#  [[423  69]
#  [ 72  22]]
# Classifier: RandomForestClassifier
# Recall: 0.02127659574468085
# Precision: 0.2
# Confusion Matrix:
#  [[484   8]
#  [ 92   2]]
# Classifier: KNeighborsClassifier
# Recall: 0.02127659574468085
# Precision: 0.11764705882352941
# Confusion Matrix:
#  [[477  15]
#  [ 92   2]]
# Classifier: SVC
# Recall: 0.0
# Precision: 0.0
# Confusion Matrix:
#  [[492   0]
#  [ 94   0]]
# Classifier: GaussianNB
# Recall: 0.24468085106382978
# Precision: 0.36507936507936506
# Confusion Matrix:
#  [[452  40]
#  [ 71  23]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.86      0.92      0.89       492
#            1       0.37      0.24      0.29        94
#
# ...
